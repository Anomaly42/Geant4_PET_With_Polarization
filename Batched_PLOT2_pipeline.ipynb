# %%
# !pip install -r ../requirements.txt
# !pip3 install --pre torch torchvision torchaudio --index-url https://download.pytorch.org/whl/nightly/cpu

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import uproot
import time

# import torch

# %%
file_path = "../../sim_first/build/plot_1e7.root"
file = uproot.open(file_path)
time_ns = file['Photons']['fTime'].array(library='np')

# %% [markdown]
# Note that we can't convert this numpy array (which is in float64) to float32 without compromising the timing accuracy, and the MPS backend doesn't support float64. So, we will sort in numpy and get the time coincidence pairs, and only then do tensor stuff.

# %%
time_ns_sorted_index = np.argsort(time_ns)

# %%
time_ns = time_ns[time_ns_sorted_index]

# %%
def time_window_filter(time_ns : np.array, window_ns):
    coincidences = []
    for i in range(len(time_ns)):
        temp_coincidences = []
        j = i + 1
        while j < len(time_ns) and abs(time_ns[i] - time_ns[j]) < window_ns:
            temp_coincidences.append((i, j))
            j += 1
        coincidences += temp_coincidences
    return coincidences

# %% [markdown]
# ### Code for a Basic Timing Check

# %%
# time_window_coincidences = time_window_filter(time_ns, 4)

# %%
# time_window_coincidences = np.array(time_window_coincidences)

# %% [markdown]
# That was pretty slow; and I don't think we can do much better unless we use Cython or something.
# A simple for loop takes 30 seconds:

# %%
# temp = 0
# for i in range(len(time_ns)):
#     temp += time_ns[i]

# %% [markdown]
# We have now got the indices that will sort the corresponding columns, and the timing coincidence (n, 2) list of pairs. Time to start batching!

# %%
def load_data_and_slice(root_file, col_name, start, end):
    print(f"Function Begins: Loading {col_name} from {start} to {end}")
    start_time = time.time()
    print("Loading Data...")
    data = root_file['Photons'][col_name].array(library='np')
    print("Data Loaded. Took {} seconds".format(time.time() - start_time))
    print("Sorting Data...")
    data = data[time_ns_sorted_index]
    print("Data Sorted. Took {} seconds".format(time.time() - start_time))
    print("Slicing Data...")
    data = data[start:end]
    print("Data Sliced. Took {} seconds".format(time.time() - start_time))

    # print("Converting Numpy Array Datatype")
    # if col_name == 'fEventID':
    #     data = data.astype('int64')
    # else:
    #     data = data.astype('float32')
    # print("Data Conversion Complete. Took {} seconds".format(time.time() - start_time))

    # print("Converting Numpy Array to Torch Tensor")
    # data = torch.from_numpy(data).to(DEVICE)
    # print("Data Conversion Complete. Took {} seconds".format(time.time() - start_time))
    return data

# %%
# eventID_0_10000 = load_data_and_slice(file, 'fEvent', 0, 10000)

# %%
def angle_between_vectors(v1, v2):
    #v1 and v2 are arrays of shape (3,)
    #returns a float

    return np.arccos(np.sum(v1*v2)/(np.linalg.norm(v1)*np.linalg.norm(v2)))


def vectorized_angle_between_vectors(v1_array, v2_array):
    #v1 and v2 are arrays of shape (n, 3)
    #returns an array of shape (n, 1)

    return np.arccos(np.sum(v1_array*v2_array, axis=1)/(np.linalg.norm(v1_array, axis=1)*np.linalg.norm(v2_array, axis=1)))

def vectorized_normaldotprod_between_vectors(v1_array, v2_array):
    #v1 and v2 are arrays of shape (n, 3)
    #returns an array of shape (n, 1)

    return np.sum(v1_array*v2_array, axis=1)/(np.linalg.norm(v1_array, axis=1)*np.linalg.norm(v2_array, axis=1))

def energy_filter(coincidences, energy_keV_blurred, energy_keV_min, energy_keV_max):
    #so the coincidence array has shape (n, 2)
    #we want to filter out the rows where the energy of both events is not in the specified range

    #we will do this by first creating a boolean array of shape (n, 2) where the value is True if the energy is in the specified range
    #and then we will check if both values in the row are True
    #this will give us a boolean array of shape (n, 1)
    #we will then use this array to index the coincidence array and get the filtered coincidences

    #create the boolean array
    bool_array = np.array([(energy_keV_min < energy_keV_blurred[coincidences[:, 0]]) \
         & (energy_keV_blurred[coincidences[:, 0]] < energy_keV_max), \
            (energy_keV_min < energy_keV_blurred[coincidences[:, 1]]) \
         & (energy_keV_blurred[coincidences[:, 1]] < energy_keV_max)])
    bool_array = np.transpose(bool_array)

    #check if both values in the row are True
    bool_array = np.all(bool_array, axis=1)

    #index the coincidence array
    filtered_coincidences = coincidences[bool_array]

    return filtered_coincidences

def count_true_in_filtered_coincidences(eventID, coincidences, x_mm, y_mm, z_mm):
    coincidences = np.array(coincidences)
    cond1 = (eventID[coincidences[:, 0]] == eventID[coincidences[:, 1]])
    #condition 2 is that te events should be roughly diametrically opposite
    #we will use the dot product of the polarisation vectors to check this
    #the dot product of two vectors is 1 if they are parallel, -1 if they are anti-parallel and 0 if they are perpendicular
    #so we will check if the dot product is less than -0.9
    v1 = np.array([x_mm[coincidences[:, 0]], y_mm[coincidences[:, 0]], z_mm[coincidences[:, 0]]]).T
    v2 = np.array([x_mm[coincidences[:, 1]], y_mm[coincidences[:, 1]], z_mm[coincidences[:, 1]]]).T
    cond2 = (vectorized_normaldotprod_between_vectors(v1, v2) < -0.9)
    return np.sum(cond1 & cond2)

def polarization_filter(coincidences, pol_angle_diff_blurred, angle_diff_min, angle_diff_max):
    bool_array = (pol_angle_diff_blurred > angle_diff_min) & (pol_angle_diff_blurred < angle_diff_max)
    return coincidences[bool_array]

def full_pipeline( #assume everything sorted wrt time_ns
        time_window_coincidences, 
        energy_keV,
        x_mm,
        y_mm,
        z_mm,
        polX,
        polY,
        polZ,
        eventID,
):
    energy_keV_blurred = np.random.normal(energy_keV, 0.1*energy_keV)
    energy_coincidences = energy_filter(time_window_coincidences, energy_keV_blurred, 350.0, 650.0)
    true_in_energy_filtered_count = count_true_in_filtered_coincidences(eventID, energy_coincidences, x_mm, y_mm, z_mm)
    total_in_energy_filtered_count = len(energy_coincidences)

    polX_1 = polX[time_window_coincidences[:, 0]]
    polY_1 = polY[time_window_coincidences[:, 0]]
    polZ_1 = polZ[time_window_coincidences[:, 0]]

    polX_2 = polX[time_window_coincidences[:, 1]]
    polY_2 = polY[time_window_coincidences[:, 1]]
    polZ_2 = polZ[time_window_coincidences[:, 1]]

    v1 = np.array([polX_1, polY_1, polZ_1]).T
    v2 = np.array([polX_2, polY_2, polZ_2]).T

    pol_angle_diff = vectorized_angle_between_vectors(v1, v2)
    pol_angle_diff_blurred = np.random.normal(pol_angle_diff, 0.1*np.abs(pol_angle_diff))

    polarization_coincidences = polarization_filter(time_window_coincidences, pol_angle_diff_blurred, 1.075, 2.000)
    true_in_polarization_filtered_count = count_true_in_filtered_coincidences(eventID, polarization_coincidences, x_mm, y_mm, z_mm)
    total_in_polarization_filtered_count = len(polarization_coincidences)

    energy_and_polarization_coincidences = energy_filter(polarization_coincidences, energy_keV_blurred, 350.0, 650.0)
    true_in_energy_and_polarization_filtered_count = count_true_in_filtered_coincidences(eventID, energy_and_polarization_coincidences, x_mm, y_mm, z_mm)
    total_in_energy_and_polarization_filtered_count = len(energy_and_polarization_coincidences)

    return len(x_mm), \
    len(time_window_coincidences), \
    true_in_energy_filtered_count, \
    total_in_energy_filtered_count, \
    true_in_polarization_filtered_count, \
    total_in_polarization_filtered_count, \
    true_in_energy_and_polarization_filtered_count, \
    total_in_energy_and_polarization_filtered_count

# %%
def batched_pipeline(batch_count):
    #batch_size, taking into account the last batch
    batch_size = int((len(time_ns) + (batch_count - 1))/batch_count) #ceil division
    cum_array = np.zeros((batch_count, 8), dtype='int64')

    print("Starting Batched Pipeline")
    global_start_time = time.time()
    for i in range(batch_count):
        print("Batch {} of {}".format(i+1, batch_count))
        batch_start_time = time.time()
        start = i*batch_size
        end = min((i+1)*batch_size, len(time_ns))
        time_ns_batch = time_ns[start:end]
        time_window_coincidences_batch = time_window_filter(time_ns_batch, 4) #we WILL be losing coincidences across two batches, but they are small in number
        time_window_coincidences_batch = np.array(time_window_coincidences_batch)
        energy_keV_batch = load_data_and_slice(file, 'fEnergy', start, end)/1000.0 #convert to keV from eV from file
        x_mm_batch = load_data_and_slice(file, 'fX', start, end)
        y_mm_batch = load_data_and_slice(file, 'fY', start, end)
        z_mm_batch = load_data_and_slice(file, 'fZ', start, end)
        polX_batch = load_data_and_slice(file, 'fPolX', start, end)
        polY_batch = load_data_and_slice(file, 'fPolY', start, end)
        polZ_batch = load_data_and_slice(file, 'fPolZ', start, end)
        eventID_batch = load_data_and_slice(file, 'fEvent', start, end)
        
        temp_array = np.array(list(full_pipeline(
            time_window_coincidences_batch, 
            energy_keV_batch,
            x_mm_batch,
            y_mm_batch,
            z_mm_batch,
            polX_batch,
            polY_batch,
            polZ_batch,
            eventID_batch,
        )))

        print(temp_array)
        cum_array[i] = temp_array

        print("Batch {} of {} Complete. Took {} seconds".format(i+1, batch_count, time.time() - batch_start_time))

    print("Batched Pipeline Complete. Took {} seconds".format(time.time() - global_start_time))
    print(cum_array)
    return cum_array

# %%
final_array = batched_pipeline(10)
# Out:
# Starting Batched Pipeline
# Batch 1 of 10
# Function Begins: Loading fEnergy from 0 to 202215
# Loading Data...
# Data Loaded. Took 0.1347029209136963 seconds
# Sorting Data...
# Data Sorted. Took 0.1462700366973877 seconds
# Slicing Data...
# Data Sliced. Took 0.14631104469299316 seconds
# Function Begins: Loading fX from 0 to 202215
# Loading Data...
# Data Loaded. Took 0.24605298042297363 seconds
# Sorting Data...
# Data Sorted. Took 0.2550680637359619 seconds
# Slicing Data...
# Data Sliced. Took 0.2551000118255615 seconds
# Function Begins: Loading fY from 0 to 202215
# Loading Data...
# Data Loaded. Took 0.16139602661132812 seconds
# Sorting Data...
# Data Sorted. Took 0.16968679428100586 seconds
# Slicing Data...
# Data Sliced. Took 0.16973495483398438 seconds
# Function Begins: Loading fZ from 0 to 202215
# Loading Data...
# Data Loaded. Took 0.13572907447814941 seconds
# Sorting Data...
# Data Sorted. Took 0.14412212371826172 seconds
# Slicing Data...
# Data Sliced. Took 0.14415502548217773 seconds
# Function Begins: Loading fPolX from 0 to 202215
# Loading Data...
# Data Loaded. Took 0.21799492835998535 seconds
# Sorting Data...
# Data Sorted. Took 0.22955584526062012 seconds
# Slicing Data...
# Data Sliced. Took 0.22958898544311523 seconds
# Function Begins: Loading fPolY from 0 to 202215
# Loading Data...
# Data Loaded. Took 0.15674901008605957 seconds
# Sorting Data...
# Data Sorted. Took 0.16525483131408691 seconds
# Slicing Data...
# Data Sliced. Took 0.16527390480041504 seconds
# Function Begins: Loading fPolZ from 0 to 202215
# Loading Data...
# Data Loaded. Took 0.17765092849731445 seconds
# Sorting Data...
# Data Sorted. Took 0.18432307243347168 seconds
# Slicing Data...
# Data Sliced. Took 0.18435406684875488 seconds
# Function Begins: Loading fEvent from 0 to 202215
# Loading Data...
# Data Loaded. Took 0.10079097747802734 seconds
# Sorting Data...
# Data Sorted. Took 0.10724616050720215 seconds
# Slicing Data...
# Data Sliced. Took 0.10726404190063477 seconds
# [202215 102687  84038  85499  82215  82803  81586  82161]
# Batch 1 of 10 Complete. Took 1.5333986282348633 seconds
# Batch 2 of 10
# /var/folders/t0/kz8yxky97yg56bbdw_h8qs100000gn/T/ipykernel_89254/3422969115.py:12: RuntimeWarning: invalid value encountered in divide
#   return np.arccos(np.sum(v1_array*v2_array, axis=1)/(np.linalg.norm(v1_array, axis=1)*np.linalg.norm(v2_array, axis=1)))
# Function Begins: Loading fEnergy from 202215 to 404430
# Loading Data...
# Data Loaded. Took 0.07685017585754395 seconds
# Sorting Data...
# Data Sorted. Took 0.0865020751953125 seconds
# Slicing Data...
# Data Sliced. Took 0.08653903007507324 seconds
# Function Begins: Loading fX from 202215 to 404430
# Loading Data...
# Data Loaded. Took 0.11656904220581055 seconds
# Sorting Data...
# Data Sorted. Took 0.12671494483947754 seconds
# Slicing Data...
# Data Sliced. Took 0.1268758773803711 seconds
# Function Begins: Loading fY from 202215 to 404430
# Loading Data...
# Data Loaded. Took 0.12171077728271484 seconds
# Sorting Data...
# Data Sorted. Took 0.1312577724456787 seconds
# Slicing Data...
# Data Sliced. Took 0.13129091262817383 seconds
# Function Begins: Loading fZ from 202215 to 404430
# Loading Data...
# Data Loaded. Took 0.11772394180297852 seconds
# Sorting Data...
# Data Sorted. Took 0.1268160343170166 seconds
# Slicing Data...
# Data Sliced. Took 0.12687301635742188 seconds
# Function Begins: Loading fPolX from 202215 to 404430
# Loading Data...
# Data Loaded. Took 0.1205599308013916 seconds
# Sorting Data...
# Data Sorted. Took 0.12821626663208008 seconds
# Slicing Data...
# Data Sliced. Took 0.12825822830200195 seconds
# Function Begins: Loading fPolY from 202215 to 404430
# Loading Data...
# Data Loaded. Took 0.11551284790039062 seconds
# Sorting Data...
# Data Sorted. Took 0.12465310096740723 seconds
# Slicing Data...
# Data Sliced. Took 0.12468624114990234 seconds
# Function Begins: Loading fPolZ from 202215 to 404430
# Loading Data...
# Data Loaded. Took 0.11450004577636719 seconds
# Sorting Data...
# Data Sorted. Took 0.12283492088317871 seconds
# Slicing Data...
# Data Sliced. Took 0.12287116050720215 seconds
# Function Begins: Loading fEvent from 202215 to 404430
# Loading Data...
# Data Loaded. Took 0.08727502822875977 seconds
# Sorting Data...
# Data Sorted. Took 0.09669017791748047 seconds
# Slicing Data...
# Data Sliced. Took 0.09672236442565918 seconds
# [202215 102882  83944  85365  82182  82743  81469  82014]
# Batch 2 of 10 Complete. Took 1.0711019039154053 seconds
# Batch 3 of 10
# Function Begins: Loading fEnergy from 404430 to 606645
# Loading Data...
# Data Loaded. Took 0.07523703575134277 seconds
# Sorting Data...
# Data Sorted. Took 0.08253693580627441 seconds
# Slicing Data...
# Data Sliced. Took 0.08256196975708008 seconds
# Function Begins: Loading fX from 404430 to 606645
# Loading Data...
# Data Loaded. Took 0.11557602882385254 seconds
# Sorting Data...
# Data Sorted. Took 0.12246203422546387 seconds
# Slicing Data...
# Data Sliced. Took 0.12248921394348145 seconds
# Function Begins: Loading fY from 404430 to 606645
# Loading Data...
# Data Loaded. Took 0.11459827423095703 seconds
# Sorting Data...
# Data Sorted. Took 0.12110209465026855 seconds
# Slicing Data...
# Data Sliced. Took 0.12112927436828613 seconds
# Function Begins: Loading fZ from 404430 to 606645
# Loading Data...
# Data Loaded. Took 0.11023402214050293 seconds
# Sorting Data...
# Data Sorted. Took 0.11688399314880371 seconds
# Slicing Data...
# Data Sliced. Took 0.1169118881225586 seconds
# Function Begins: Loading fPolX from 404430 to 606645
# Loading Data...
# Data Loaded. Took 0.10886812210083008 seconds
# Sorting Data...
# Data Sorted. Took 0.1149592399597168 seconds
# Slicing Data...
# Data Sliced. Took 0.11498117446899414 seconds
# Function Begins: Loading fPolY from 404430 to 606645
# Loading Data...
# Data Loaded. Took 0.10959219932556152 seconds
# Sorting Data...
# Data Sorted. Took 0.11542916297912598 seconds
# Slicing Data...
# Data Sliced. Took 0.11544513702392578 seconds
# Function Begins: Loading fPolZ from 404430 to 606645
# Loading Data...
# Data Loaded. Took 0.11000514030456543 seconds
# Sorting Data...
# Data Sorted. Took 0.11594510078430176 seconds
# Slicing Data...
# Data Sliced. Took 0.11596322059631348 seconds
# Function Begins: Loading fEvent from 404430 to 606645
# Loading Data...
# Data Loaded. Took 0.0796358585357666 seconds
# Sorting Data...
# Data Sorted. Took 0.0855717658996582 seconds
# Slicing Data...
# Data Sliced. Took 0.08558893203735352 seconds
# [202215 102938  83919  85376  82060  82660  81298  81884]
# Batch 3 of 10 Complete. Took 1.0006320476531982 seconds
# Batch 4 of 10
# Function Begins: Loading fEnergy from 606645 to 808860
# Loading Data...
# Data Loaded. Took 0.0749201774597168 seconds
# Sorting Data...
# Data Sorted. Took 0.0831601619720459 seconds
# Slicing Data...
# Data Sliced. Took 0.08319807052612305 seconds
# Function Begins: Loading fX from 606645 to 808860
# Loading Data...
# Data Loaded. Took 0.11640787124633789 seconds
# Sorting Data...
# Data Sorted. Took 0.12453603744506836 seconds
# Slicing Data...
# Data Sliced. Took 0.12464022636413574 seconds
# Function Begins: Loading fY from 606645 to 808860
# Loading Data...
# Data Loaded. Took 0.11687397956848145 seconds
# Sorting Data...
# Data Sorted. Took 0.12351107597351074 seconds
# Slicing Data...
# Data Sliced. Took 0.12352585792541504 seconds
# Function Begins: Loading fZ from 606645 to 808860
# Loading Data...
# Data Loaded. Took 0.11251616477966309 seconds
# Sorting Data...
# Data Sorted. Took 0.11877822875976562 seconds
# Slicing Data...
# Data Sliced. Took 0.1188051700592041 seconds
# Function Begins: Loading fPolX from 606645 to 808860
# Loading Data...
# Data Loaded. Took 0.11160802841186523 seconds
# Sorting Data...
# Data Sorted. Took 0.1176760196685791 seconds
# Slicing Data...
# Data Sliced. Took 0.1177070140838623 seconds
# Function Begins: Loading fPolY from 606645 to 808860
# Loading Data...
# Data Loaded. Took 0.2785830497741699 seconds
# Sorting Data...
# Data Sorted. Took 0.28568601608276367 seconds
# Slicing Data...
# Data Sliced. Took 0.2857179641723633 seconds
# Function Begins: Loading fPolZ from 606645 to 808860
# Loading Data...
# Data Loaded. Took 0.1130073070526123 seconds
# Sorting Data...
# Data Sorted. Took 0.1216120719909668 seconds
# Slicing Data...
# Data Sliced. Took 0.12164831161499023 seconds
# Function Begins: Loading fEvent from 606645 to 808860
# Loading Data...
# Data Loaded. Took 0.08232903480529785 seconds
# Sorting Data...
# Data Sorted. Took 0.09118413925170898 seconds
# Slicing Data...
# Data Sliced. Took 0.09122204780578613 seconds
# [202215 103489  83857  85354  82047  82694  81315  81945]
# Batch 4 of 10 Complete. Took 1.1926507949829102 seconds
# Batch 5 of 10
# Function Begins: Loading fEnergy from 808860 to 1011075
# Loading Data...
# Data Loaded. Took 0.07276010513305664 seconds
# Sorting Data...
# Data Sorted. Took 0.08161306381225586 seconds
# Slicing Data...
# Data Sliced. Took 0.08164000511169434 seconds
# Function Begins: Loading fX from 808860 to 1011075
# Loading Data...
# Data Loaded. Took 0.11616206169128418 seconds
# Sorting Data...
# Data Sorted. Took 0.12377500534057617 seconds
# Slicing Data...
# Data Sliced. Took 0.12380695343017578 seconds
# Function Begins: Loading fY from 808860 to 1011075
# Loading Data...
# Data Loaded. Took 0.11477994918823242 seconds
# Sorting Data...
# Data Sorted. Took 0.12159109115600586 seconds
# Slicing Data...
# Data Sliced. Took 0.12161684036254883 seconds
# Function Begins: Loading fZ from 808860 to 1011075
# Loading Data...
# Data Loaded. Took 0.11107802391052246 seconds
# Sorting Data...
# Data Sorted. Took 0.11755013465881348 seconds
# Slicing Data...
# Data Sliced. Took 0.11757707595825195 seconds
# Function Begins: Loading fPolX from 808860 to 1011075
# Loading Data...
# Data Loaded. Took 0.1135859489440918 seconds
# Sorting Data...
# Data Sorted. Took 0.12183594703674316 seconds
# Slicing Data...
# Data Sliced. Took 0.12185907363891602 seconds
# Function Begins: Loading fPolY from 808860 to 1011075
# Loading Data...
# Data Loaded. Took 0.11473298072814941 seconds
# Sorting Data...
# Data Sorted. Took 0.12266898155212402 seconds
# Slicing Data...
# Data Sliced. Took 0.12272906303405762 seconds
# Function Begins: Loading fPolZ from 808860 to 1011075
# Loading Data...
# Data Loaded. Took 0.11623501777648926 seconds
# Sorting Data...
# Data Sorted. Took 0.1238400936126709 seconds
# Slicing Data...
# Data Sliced. Took 0.12386894226074219 seconds
# Function Begins: Loading fEvent from 808860 to 1011075
# Loading Data...
# Data Loaded. Took 0.08365392684936523 seconds
# Sorting Data...
# Data Sorted. Took 0.09086203575134277 seconds
# Slicing Data...
# Data Sliced. Took 0.09089112281799316 seconds
# [202215 103226  83954  85461  82197  82825  81441  82050]
# Batch 5 of 10 Complete. Took 1.0334887504577637 seconds
# Batch 6 of 10
# Function Begins: Loading fEnergy from 1011075 to 1213290
# Loading Data...
# Data Loaded. Took 0.07664012908935547 seconds
# Sorting Data...
# Data Sorted. Took 0.08337211608886719 seconds
# Slicing Data...
# Data Sliced. Took 0.08340597152709961 seconds
# Function Begins: Loading fX from 1011075 to 1213290
# Loading Data...
# Data Loaded. Took 0.11832618713378906 seconds
# Sorting Data...
# Data Sorted. Took 0.12672686576843262 seconds
# Slicing Data...
# Data Sliced. Took 0.1268479824066162 seconds
# Function Begins: Loading fY from 1011075 to 1213290
# Loading Data...
# Data Loaded. Took 0.12227892875671387 seconds
# Sorting Data...
# Data Sorted. Took 0.1299290657043457 seconds
# Slicing Data...
# Data Sliced. Took 0.1299610137939453 seconds
# Function Begins: Loading fZ from 1011075 to 1213290
# Loading Data...
# Data Loaded. Took 0.11503219604492188 seconds
# Sorting Data...
# Data Sorted. Took 0.12237000465393066 seconds
# Slicing Data...
# Data Sliced. Took 0.12240314483642578 seconds
# Function Begins: Loading fPolX from 1011075 to 1213290
# Loading Data...
# Data Loaded. Took 0.11180377006530762 seconds
# Sorting Data...
# Data Sorted. Took 0.11971187591552734 seconds
# Slicing Data...
# Data Sliced. Took 0.11974406242370605 seconds
# Function Begins: Loading fPolY from 1011075 to 1213290
# Loading Data...
# Data Loaded. Took 0.11080694198608398 seconds
# Sorting Data...
# Data Sorted. Took 0.1176750659942627 seconds
# Slicing Data...
# Data Sliced. Took 0.11771202087402344 seconds
# Function Begins: Loading fPolZ from 1011075 to 1213290
# Loading Data...
# Data Loaded. Took 0.11409616470336914 seconds
# Sorting Data...
# Data Sorted. Took 0.12089800834655762 seconds
# Slicing Data...
# Data Sliced. Took 0.1209259033203125 seconds
# Function Begins: Loading fEvent from 1011075 to 1213290
# Loading Data...
# Data Loaded. Took 0.08630084991455078 seconds
# Sorting Data...
# Data Sorted. Took 0.09478497505187988 seconds
# Slicing Data...
# Data Sliced. Took 0.09481692314147949 seconds
# [202215 103324  83876  85268  82048  82582  81314  81840]
# Batch 6 of 10 Complete. Took 1.0447568893432617 seconds
# Batch 7 of 10
# Function Begins: Loading fEnergy from 1213290 to 1415505
# Loading Data...
# Data Loaded. Took 0.07589316368103027 seconds
# Sorting Data...
# Data Sorted. Took 0.08418488502502441 seconds
# Slicing Data...
# Data Sliced. Took 0.0842130184173584 seconds
# Function Begins: Loading fX from 1213290 to 1415505
# Loading Data...
# Data Loaded. Took 0.11842799186706543 seconds
# Sorting Data...
# Data Sorted. Took 0.12611603736877441 seconds
# Slicing Data...
# Data Sliced. Took 0.12613391876220703 seconds
# Function Begins: Loading fY from 1213290 to 1415505
# Loading Data...
# Data Loaded. Took 0.11789894104003906 seconds
# Sorting Data...
# Data Sorted. Took 0.12568879127502441 seconds
# Slicing Data...
# Data Sliced. Took 0.1257169246673584 seconds
# Function Begins: Loading fZ from 1213290 to 1415505
# Loading Data...
# Data Loaded. Took 0.11498022079467773 seconds
# Sorting Data...
# Data Sorted. Took 0.12425017356872559 seconds
# Slicing Data...
# Data Sliced. Took 0.1242821216583252 seconds
# Function Begins: Loading fPolX from 1213290 to 1415505
# Loading Data...
# Data Loaded. Took 0.11086177825927734 seconds
# Sorting Data...
# Data Sorted. Took 0.11745786666870117 seconds
# Slicing Data...
# Data Sliced. Took 0.11748409271240234 seconds
# Function Begins: Loading fPolY from 1213290 to 1415505
# Loading Data...
# Data Loaded. Took 0.10899615287780762 seconds
# Sorting Data...
# Data Sorted. Took 0.11536884307861328 seconds
# Slicing Data...
# Data Sliced. Took 0.11539912223815918 seconds
# Function Begins: Loading fPolZ from 1213290 to 1415505
# Loading Data...
# Data Loaded. Took 0.11179304122924805 seconds
# Sorting Data...
# Data Sorted. Took 0.11783695220947266 seconds
# Slicing Data...
# Data Sliced. Took 0.11787104606628418 seconds
# Function Begins: Loading fEvent from 1213290 to 1415505
# Loading Data...
# Data Loaded. Took 0.0785210132598877 seconds
# Sorting Data...
# Data Sorted. Took 0.08436298370361328 seconds
# Slicing Data...
# Data Sliced. Took 0.08437800407409668 seconds
# [202215 103156  83919  85310  82066  82619  81352  81892]
# Batch 7 of 10 Complete. Took 1.0241138935089111 seconds
# Batch 8 of 10
# Function Begins: Loading fEnergy from 1415505 to 1617720
# Loading Data...
# Data Loaded. Took 0.07156109809875488 seconds
# Sorting Data...
# Data Sorted. Took 0.0774080753326416 seconds
# Slicing Data...
# Data Sliced. Took 0.0774381160736084 seconds
# Function Begins: Loading fX from 1415505 to 1617720
# Loading Data...
# Data Loaded. Took 0.1085660457611084 seconds
# Sorting Data...
# Data Sorted. Took 0.11458587646484375 seconds
# Slicing Data...
# Data Sliced. Took 0.11462211608886719 seconds
# Function Begins: Loading fY from 1415505 to 1617720
# Loading Data...
# Data Loaded. Took 0.11215996742248535 seconds
# Sorting Data...
# Data Sorted. Took 0.1181488037109375 seconds
# Slicing Data...
# Data Sliced. Took 0.11816787719726562 seconds
# Function Begins: Loading fZ from 1415505 to 1617720
# Loading Data...
# Data Loaded. Took 0.10792207717895508 seconds
# Sorting Data...
# Data Sorted. Took 0.11543607711791992 seconds
# Slicing Data...
# Data Sliced. Took 0.11546611785888672 seconds
# Function Begins: Loading fPolX from 1415505 to 1617720
# Loading Data...
# Data Loaded. Took 0.10800004005432129 seconds
# Sorting Data...
# Data Sorted. Took 0.1142892837524414 seconds
# Slicing Data...
# Data Sliced. Took 0.11430716514587402 seconds
# Function Begins: Loading fPolY from 1415505 to 1617720
# Loading Data...
# Data Loaded. Took 0.10891580581665039 seconds
# Sorting Data...
# Data Sorted. Took 0.11515283584594727 seconds
# Slicing Data...
# Data Sliced. Took 0.11518573760986328 seconds
# Function Begins: Loading fPolZ from 1415505 to 1617720
# Loading Data...
# Data Loaded. Took 0.10780882835388184 seconds
# Sorting Data...
# Data Sorted. Took 0.11368393898010254 seconds
# Slicing Data...
# Data Sliced. Took 0.11370277404785156 seconds
# Function Begins: Loading fEvent from 1415505 to 1617720
# Loading Data...
# Data Loaded. Took 0.07985210418701172 seconds
# Sorting Data...
# Data Sorted. Took 0.08607888221740723 seconds
# Slicing Data...
# Data Sliced. Took 0.08609795570373535 seconds
# [202215 103119  83679  85258  81867  82504  81091  81708]
# Batch 8 of 10 Complete. Took 0.9777939319610596 seconds
# Batch 9 of 10
# Function Begins: Loading fEnergy from 1617720 to 1819935
# Loading Data...
# Data Loaded. Took 0.07434415817260742 seconds
# Sorting Data...
# Data Sorted. Took 0.08079099655151367 seconds
# Slicing Data...
# Data Sliced. Took 0.08081817626953125 seconds
# Function Begins: Loading fX from 1617720 to 1819935
# Loading Data...
# Data Loaded. Took 0.11695003509521484 seconds
# Sorting Data...
# Data Sorted. Took 0.12315201759338379 seconds
# Slicing Data...
# Data Sliced. Took 0.12318205833435059 seconds
# Function Begins: Loading fY from 1617720 to 1819935
# Loading Data...
# Data Loaded. Took 0.11377382278442383 seconds
# Sorting Data...
# Data Sorted. Took 0.1201019287109375 seconds
# Slicing Data...
# Data Sliced. Took 0.12013697624206543 seconds
# Function Begins: Loading fZ from 1617720 to 1819935
# Loading Data...
# Data Loaded. Took 0.10819387435913086 seconds
# Sorting Data...
# Data Sorted. Took 0.11412787437438965 seconds
# Slicing Data...
# Data Sliced. Took 0.11414194107055664 seconds
# Function Begins: Loading fPolX from 1617720 to 1819935
# Loading Data...
# Data Loaded. Took 0.10724115371704102 seconds
# Sorting Data...
# Data Sorted. Took 0.1133880615234375 seconds
# Slicing Data...
# Data Sliced. Took 0.11340618133544922 seconds
# Function Begins: Loading fPolY from 1617720 to 1819935
# Loading Data...
# Data Loaded. Took 0.10614490509033203 seconds
# Sorting Data...
# Data Sorted. Took 0.11295914649963379 seconds
# Slicing Data...
# Data Sliced. Took 0.1129920482635498 seconds
# Function Begins: Loading fPolZ from 1617720 to 1819935
# Loading Data...
# Data Loaded. Took 0.10845303535461426 seconds
# Sorting Data...
# Data Sorted. Took 0.11473608016967773 seconds
# Slicing Data...
# Data Sliced. Took 0.11475515365600586 seconds
# Function Begins: Loading fEvent from 1617720 to 1819935
# Loading Data...
# Data Loaded. Took 0.0780789852142334 seconds
# Sorting Data...
# Data Sorted. Took 0.08408594131469727 seconds
# Slicing Data...
# Data Sliced. Took 0.08410382270812988 seconds
# [202215 103012  83986  85456  82197  82766  81535  82092]
# Batch 9 of 10 Complete. Took 0.9868381023406982 seconds
# Batch 10 of 10
# Function Begins: Loading fEnergy from 1819935 to 2022146
# Loading Data...
# Data Loaded. Took 0.07213687896728516 seconds
# Sorting Data...
# Data Sorted. Took 0.07814288139343262 seconds
# Slicing Data...
# Data Sliced. Took 0.07817292213439941 seconds
# Function Begins: Loading fX from 1819935 to 2022146
# Loading Data...
# Data Loaded. Took 0.11241698265075684 seconds
# Sorting Data...
# Data Sorted. Took 0.11850905418395996 seconds
# Slicing Data...
# Data Sliced. Took 0.11852312088012695 seconds
# Function Begins: Loading fY from 1819935 to 2022146
# Loading Data...
# Data Loaded. Took 0.11255598068237305 seconds
# Sorting Data...
# Data Sorted. Took 0.11891484260559082 seconds
# Slicing Data...
# Data Sliced. Took 0.11893296241760254 seconds
# Function Begins: Loading fZ from 1819935 to 2022146
# Loading Data...
# Data Loaded. Took 0.10856413841247559 seconds
# Sorting Data...
# Data Sorted. Took 0.11590003967285156 seconds
# Slicing Data...
# Data Sliced. Took 0.11594009399414062 seconds
# Function Begins: Loading fPolX from 1819935 to 2022146
# Loading Data...
# Data Loaded. Took 0.11082100868225098 seconds
# Sorting Data...
# Data Sorted. Took 0.11731505393981934 seconds
# Slicing Data...
# Data Sliced. Took 0.117340087890625 seconds
# Function Begins: Loading fPolY from 1819935 to 2022146
# Loading Data...
# Data Loaded. Took 0.10722827911376953 seconds
# Sorting Data...
# Data Sorted. Took 0.11318492889404297 seconds
# Slicing Data...
# Data Sliced. Took 0.11320018768310547 seconds
# Function Begins: Loading fPolZ from 1819935 to 2022146
# Loading Data...
# Data Loaded. Took 0.1082921028137207 seconds
# Sorting Data...
# Data Sorted. Took 0.11435794830322266 seconds
# Slicing Data...
# Data Sliced. Took 0.11437702178955078 seconds
# Function Begins: Loading fEvent from 1819935 to 2022146
# Loading Data...
# Data Loaded. Took 0.08009195327758789 seconds
# Sorting Data...
# Data Sorted. Took 0.08648204803466797 seconds
# Slicing Data...
# Data Sliced. Took 0.08651304244995117 seconds
# [202211 102715  83985  85487  82127  82752  81444  82054]
# Batch 10 of 10 Complete. Took 0.9870820045471191 seconds
# Batched Pipeline Complete. Took 10.851931810379028 seconds
# [[202215 102687  84038  85499  82215  82803  81586  82161]
#  [202215 102882  83944  85365  82182  82743  81469  82014]
#  [202215 102938  83919  85376  82060  82660  81298  81884]
#  [202215 103489  83857  85354  82047  82694  81315  81945]
#  [202215 103226  83954  85461  82197  82825  81441  82050]
#  [202215 103324  83876  85268  82048  82582  81314  81840]
#  [202215 103156  83919  85310  82066  82619  81352  81892]
#  [202215 103119  83679  85258  81867  82504  81091  81708]
#  [202215 103012  83986  85456  82197  82766  81535  82092]
#  [202211 102715  83985  85487  82127  82752  81444  82054]]

# %%
final_array.sum(axis=0)
# Out:
# array([2022146, 1030548,  839157,  853834,  821006,  826948,  813845,
#         819640])

# %% [markdown]
# So at least for one batch we got:
# 20224365, 26489425, 8392283, 23172857, 8211833, 14059395
# for the data labels:
# - len(x_mm),
# - len(time_window_coincidences),
# - true_in_energy_filtered_count,
# - total_in_energy_filtered_count,
# - true_in_polarization_filtered_count,
# - total_in_polarization_filtered_count
